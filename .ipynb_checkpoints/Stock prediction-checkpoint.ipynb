# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import datetime
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers.recurrent import GRU
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from sklearn.metrics import mean_squared_error

# %%
print(tf.__version__)
print(tf.keras.__version__)
print(pd.__version__)
# Out:
# 1.4.0
# 2.0.8-tf
# 0.20.1

# %%
df = pd.read_csv('data/prices-split-adjusted.csv')
df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
print('\nnumber of different stocks: ', len(list(set(df.symbol))))
print(list(set(df.symbol))[:10])
# Out:
# number of different stocks:  501
# ['BDX', 'TMK', 'SWKS', 'ES', 'HSIC', 'HST', 'CBS', 'CELG', 'DISCA', 'XRX']

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
df_stock = df.loc[df['symbol'] == 'EQIX'].copy()
df_stock.drop(['symbol'],1,inplace=True)
df_stock.drop(['volume'],1,inplace=True)
df_stock.drop(['date'],1,inplace=True)

# %%
plt.plot(df_stock.open.values)
plt.plot(df_stock.close.values)
plt.plot(df_stock.low.values)
plt.plot(df_stock.high.values)

plt.show()

# %%
cols = list(df_stock.columns.values)
#print('df_stock.columns.values = ', cols)
#cols = list(df_stock.columns.values)
print('df_stock.columns.values = ', cols)
# Out:
# df_stock.columns.values =  ['open', 'close', 'low', 'high']

# %%
#shift the data and split in train and test set

shift_steps = 1

df_stock_shifted = df_stock.shift(-shift_steps)

x_data = df_stock_shifted[:-shift_steps]
y_data = df_stock.values[:-shift_steps]

print(x_data.shape)
print(y_data.shape)


num_data = len(x_data)
train_split = 0.9

num_train = int(train_split * num_data)
num_test = num_data - num_train


x_train = x_data[0:num_train]
x_test = x_data[num_train:]


y_train = y_data[0:num_train]
y_test = y_data[num_train:]
# Out:
# (1761, 4)
# (1761, 4)

# %%
#normalizing
x_scaler = MinMaxScaler()
x_train_scaled = x_scaler.fit_transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
xmin_value = min(x_train_scaled[0])
xmax_value = max(x_train_scaled[0])
ymin_value = min(y_train_scaled[0])
ymax_value = max(y_train_scaled[0])

print(xmin_value)
print(xmax_value)
print(ymin_value)
print(ymax_value)
# Out:
# 0.1350945246499431
# 0.1493177958709015
# 0.13362796078579736
# 0.14925601720826642

# %%
print('x_train_scaled.shape = ',x_train_scaled.shape)
print('y_train_scaled.shape = ', y_train_scaled.shape)
#print('x_valid_scaled.shape = ',x_valid_scaled.shape)
#print('y_valid_scaled.shape = ', y_valid_scaled.shape)
print('x_test_scaled.shape = ', x_test_scaled.shape)
print('y_test_scaled.shape = ',y_test_scaled.shape)
# Out:
# x_train_scaled.shape =  (1584, 4)
# y_train_scaled.shape =  (1584, 4)
# x_test_scaled.shape =  (177, 4)
# y_test_scaled.shape =  (177, 4)

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %%
batch_size = 50
seq_len = 40
num_train = len(x_train)
num_x_signals = x_train.shape[1]
num_y_signals = y_train.shape[1]

#x_train_scaled = 1
generator = batch_generator(batch_size=batch_size, 
                            sequence_length=seq_len)

# %%
x_batch, y_batch = next(generator)
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (50, 40, 4)
# (50, 40, 4)

# %%
#Keras model
model = Sequential()
input_dim = x_train.shape[1]
output_dim = 4

# %%
#LSTM
model.add(LSTM(16, activation = 'relu', input_shape=(seq_len, input_dim)))
#model.add(Dense(output_dim , activation="sigmoid"))
model.compile(loss='mean_squared_error', optimizer='adam')

#GRU
#model.add(GRU(units=256, input_shape=(seq_len-1, input_dim)))
#model.add(Dense(output_dim, activation="sigmoid"))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit_generator(generator=generator,
                    epochs=20,
                    steps_per_epoch=100,
                    #validation_data=validation_data,
                    callbacks=callbacks) #fits the model with batches from batch_generator
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-559777bf1aba> in <module>()
#       3                     steps_per_epoch=100,
#       4                     #validation_data=validation_data,
# ----> 5                     callbacks=callbacks) #fits the model with batches from batch_generator
#
# C:\Users\Aaron\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# gru_6 (GRU)                  (None, 256)               200448
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 1028
# ...
# Total params: 201,476
# Trainable params: 201,476
# Non-trainable params: 0
# _________________________________________________________________

# %%
#callback functions

path_checkpoint = "checkpoints"
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_best_only=True,
                                      save_weights_only=True)

callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=2,
                                        verbose=1)

path_log='logs'
callback_tensorboard = TensorBoard(log_dir=path_log)


callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard]

# %%
testPredict = model.predict(x_test)
print(testPredict.shape)
print(y_test.shape)
#testScore = math.sqrt(mean_squared_error(y_test, testPredict[:,0]))
#print('Test Score: %.2f RMSE' % (testScore))

fig, axes = plt.subplots(2, 2, figsize=(20,10))

axes[0, 0].plot(testPredict[:,0], label='prediction')
axes[0, 0].plot(y_test[:,0], label='true')
axes[0, 0].set_title('open', fontsize=30)
legend = axes[0,0].legend(loc='upper center', shadow=True)

axes[0, 1].plot(testPredict[:,1])
axes[0, 1].plot(y_test[:,1])
axes[0, 1].set_title('close', fontsize=30)


axes[1, 0].plot(testPredict[:,2])
axes[1, 0].plot(y_test[:,2])
axes[1, 0].set_title('low', fontsize=30)


axes[1, 1].plot(testPredict[:,3])
axes[1, 1].plot(y_test[:,3])
axes[1, 1].set_title('high', fontsize=30)


plt.show()
# Out:
# (172, 4)
# (172, 4)
